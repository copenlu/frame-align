# %%
import os

data_dir = os.path.join("../data/merged_topic_samples_jul23.csv")

# %%
# Load the data
import pandas as pd

data = pd.read_csv(data_dir)
data.head()
# Out:
#                                      id  id.1  uuid  \
# 0  f3fcf30c-093a-4acd-a90c-40a21f0091d5   0.0   0.0
# 1  17d09f84-15be-48ba-b619-e924fca17577   1.0   1.0
# 2  a856fbc0-8ab5-44ad-a3c5-83147b3f5dd9   2.0   2.0
# 3  7bd3ad37-3b31-4335-9847-07853389beb5   3.0   3.0
# 4  7f53e5a8-1c6d-4d3f-b0d6-6548da408043   4.0   4.0
#
#                                     auto_topic_label  \
# 0  crash_motorcyclist_pedestrian_driver_collision...
# 1  hiker_drowns_body_lake_mountain_drowning_river...
# 2  crane_collapses_catches_collapse_arm_commute_c...
# 3  plane_crashes_helicopter_pilot_small_crash_han...
# 4  sub_implosion_operations_suspends_exploration_...
#
#                                         article_text  \
# 0  Five people were injured in a single-vehicle r...
# 1  Man drowns saving child on Lake Michigan in Wi...
# 2  Crane fire under control after partial collaps...
# 3  Pilot remains hospitalized after passenger for...
# 4  OceanGate founder and CEO Stockton Rush Colleg...
#
# ...

# %%
# check img_url column exists
if 'img_url' in data.columns:
    print('img_url column exists')
else:
    print('img_url column does not exist')
# Out:
# img_url column does not exist
